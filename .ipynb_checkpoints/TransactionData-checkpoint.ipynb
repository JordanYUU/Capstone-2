# %% [markdown]
# # Transaction Data

# %% [markdown]
# ### Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Transaction Data

# %%
dataframe = input("Please enter the file path:")
try:
    df = pd.read_csv(dataframe)
    print('''Loaded!
    ''')
    print(df.head(10))
except FileNotFoundError:
    print(f"Error: {dataframe} could not be found.")

pd.options.display.max_rows = None
# Out:
# Please enter the file path: Transaction_Data.csv
# Loaded!
#
#    TransactionID  CustID       Date       Employee  ProductID  \
# 0          10258       1  7/17/2023  Nancy Davolio         32
# 1          10275       2   8/7/2023  Nancy Davolio         24
# 2          10275       2   8/7/2023  Nancy Davolio         59
# 3          10292       3  8/28/2023  Nancy Davolio         20
# 4          10293       4  8/29/2023  Nancy Davolio         18
# 5          10293       4  8/29/2023  Nancy Davolio         24
# 6          10293       4  8/29/2023  Nancy Davolio         63
# 7          10293       4  8/29/2023  Nancy Davolio         75
# 8          10304       4  9/12/2023  Nancy Davolio         59
# 9          10304       4  9/12/2023  Nancy Davolio         71
#
#               ProductName  VendorID                    ProductVendor  \
# 0      Mascarpone Fabioli        14          Formaggi Fortini s.r.l.
# 1        Guaran Fantstica        10        Refrescos Americanas LTDA
# ...

# %% [markdown]
# ### Data Review

# %%
df.head(50)
df.info()
df[['UnitPrice', 'Quantity', 'Subtotal', 'Tax(8%)', 'OrderTotal']].describe()
# Couldn't seem to pull the Tax and Order Total columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1353 entries, 0 to 1352
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  1353 non-null   int64
#  1   CustID         1353 non-null   int64
#  2   Date           1353 non-null   object
#  3   Employee       1353 non-null   object
#  4   ProductID      1353 non-null   int64
#  5   ProductName    1353 non-null   object
#  6   VendorID       1353 non-null   int64
#  7   ProductVendor  1353 non-null   object
#  8   UnitPrice      1353 non-null   float64
#  9   Quantity       1353 non-null   int64
#  10  Subtotal       1353 non-null   float64
#  11  Tax(8%)        1353 non-null   float64
#  12  OrderTotal     1353 non-null   float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 137.5+ KB
#          UnitPrice     Quantity     Subtotal      Tax(8%)   OrderTotal
# count  1353.000000  1353.000000  1353.000000  1353.000000  1353.000000
# ...

# %% [markdown]
# ### Normalization of data

# %%
df = df.drop(columns=['Date', 'Tax(8%)'])
df
# Out:
#       TransactionID  CustID          Employee  ProductID  \
# 0             10258       1     Nancy Davolio         32
# 1             10275       2     Nancy Davolio         24
# 2             10275       2     Nancy Davolio         59
# 3             10292       3     Nancy Davolio         20
# 4             10293       4     Nancy Davolio         18
# 5             10293       4     Nancy Davolio         24
# 6             10293       4     Nancy Davolio         63
# 7             10293       4     Nancy Davolio         75
# 8             10304       4     Nancy Davolio         59
# 9             10304       4     Nancy Davolio         71
# 10            10306       5     Nancy Davolio         30
# 11            10306       5     Nancy Davolio         53
# 12            10306       5     Nancy Davolio         54
# 13            10311       6     Nancy Davolio         42
# 14            10311       6     Nancy Davolio         69
# ...

# %% [markdown]
# ### Analysis: Vendors

# %%
df_comp = df.groupby(['ProductVendor']).sum(['Quantity', 'UnitPrice', 'OrderTotal'])
df_comp = df_comp.drop(columns=['TransactionID','CustID', 'VendorID', 'ProductID'])
df_comp
# Out:
#                                         UnitPrice  Quantity  Subtotal  \
# ProductVendor
# Aux joyeux ecclsiastiques                 3342.30       373  35474.90
# Bigfoot Breweries                          616.80       507   7797.60
# Cooperativa de Quesos 'Las Cabras'         874.20       438  10434.80
# Escargots Nouveaux                          90.10        95   1219.00
# Exotic Liquids                            1029.20       804  13394.80
# Formaggi Fortini s.r.l.                   1466.20       809  18580.40
# Forts d'rables                            1909.30       559  22716.60
# G'day, Mate                               2095.80       828  25071.60
# Gai pturage                               2245.40       674  27191.00
# Grandma Kelly's Homestead                  972.00       396  12219.00
# Heli Swaren GmbH & Co. KG                  833.19       438  10328.21
# Karkki Oy                                  703.80       557   9414.75
# ...

# %%
df_comp['OrderTotal'].plot(kind='bar', figsize=(20,15), color='y')
plt.title('Revenue By Vendor')
plt.xlabel('Vendor')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# There are a few outliers like Plutzer, Pavlova, Aux joyeux at the high end, and Escargot and others on the lower end.
#
# We can deduce that the outliers are in part due to their high unit prices, and that the overall amount of units sold has a good average across most vendors.

# %% [markdown]
# ### Analysis: Products

# %%
df_prod = df.groupby(['ProductName']).sum(['Quantity', 'UnitPrice', 'OrderTotal'])
df_prod = df_prod.drop(columns=['TransactionID', 'CustID', 'ProductID', 'VendorID'])
df_prod
# Out:
#                                   UnitPrice  Quantity  Subtotal  OrderTotal
# ProductName
# Alice Mutton                         772.20       258   9516.00    10277.28
# Aniseed Syrup                         58.00        84    800.00      864.00
# Boston Crab Meat                     393.60       250   4241.10     4580.38
# Camembert Pierrot                    870.40       373  11934.00    12888.73
# Carnarvon Tigers                    1025.00       214  12862.50    13891.50
# Chai                                 439.20       313   5169.60     5583.17
# Chang                                532.00       407   7425.20     8019.21
# Chartreuse verte                     338.40       244   4118.40     4447.87
# Chef Anton's Cajun Seasoning         242.00       163   3198.80     3454.70
# Chef Anton's Gumbo Mix                98.05        71   1376.65     1486.78
# Chocolade                             61.20        68    828.75      895.05
# ...

# %%
df_prod['OrderTotal'].plot(kind='bar', figsize=(20,15), color='b')
plt.title('Revenue By Product')
plt.xlabel('Vendor')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# Again, the outliers here are products of the same outliers from the Vendors graph.
# Most things are selling tons of units, though it may be a good idea to further invest into the average products to lessen the gap between the lowest and highest values.

# %% [markdown]
# ### Analysis: Employees

# %%
df_emp = df.groupby(['Employee']).sum(['Quantity', 'UnitPrice', 'OrderTotal'])
df_emp = df_emp.drop(columns=['CustID','VendorID', 'TransactionID', 'ProductID'])
df_emp
# Out:
#                   UnitPrice  Quantity  Subtotal  OrderTotal
# Employee
# Andrew Fuller       4042.43      1829  49583.21    53549.87
# Anne Dodsworth      2038.56       822  25215.25    27232.47
# Janet Leverling     4833.81      2552  57347.97    61935.82
# Laura Callahan      4291.63      2250  57014.73    61575.87
# Margaret Peacock    7411.25      3308  94531.50   102093.97
# Michael Suyama      2737.12      1532  34899.51    37691.47
# Nancy Davolio       5765.38      2495  69532.81    75095.44
# Robert King         2374.41      1299  29596.60    31964.33
# Steven Buchanan     1560.15      1004  21377.75    23087.99

# %%
df_emp['Quantity'].plot(kind='pie')
plt.title('Employee preformance')
plt.ylabel('')
plt.show()

# %% [markdown]
# The idea with this is to showcase who is doing well. These are people we can look to for further data samples and analysis, as well as
# bringing those who are not preforming as well to a higher standard. To bring the lowest values up is to bring the average up.

# %% [markdown]
# ### Export cleaned file

# %%
df.to_csv('Transaction_Data_New.csv', index=False)
print('New file saved in Jupyter!')
# Out:
# New file saved in Jupyter!
